# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path("../fight_calendar_x/data/calendar_raw.xlsx")

# %%
sheet_names = pd.ExcelFile(file_path).sheet_names
sheet_names.remove("テンプレート")

# %%
for sheet_name in sheet_names:
    display(pd.read_excel(file_path, sheet_name=sheet_name).head())
# Out:
#   データソース:https://www.ohashi-gym.com/
# 0                       登録日:20230514
# 1                    NTTドコモ Presents
# 2          WBC・WBO世界スーパーバンタム級タイトルマッチ
# 3                2023年7月25日（火）有明アリーナ
# 4             抽選受付開始　5月12日（金）12：00　〜
#   データソース:http://www.watanabegym.com/schedule/50/
# 0                                   登録日:20230514
# 1                     5月3日（水）大阪・和泉シティプラザ／13:00開始
# 2                                   スーパーバンタム級 4R
# 3                        中林 稜太郎 vs 中逵 友太（ディアマンテ）
# 4                         5月19日（金）後楽園ホール／18:00開始
#            データソース:https://teiken.com/bout/index.html
# 0                                       登録日:20230514
# 1                                ＜５月２０日／東京・墨田区総合体育館＞
# 2  バンタム級８回戦／増田陸（２戦２勝２ＫＯ）　対　日本同級２位、ＷＢＯアジアパシフィック同級１...
# 3                                      ＜６月３日／後楽園ホール＞
# 4  スーパーバンタム級８回戦／日本同級１３位、福井勝也（４戦全勝３ＫＯ）　対　韓国同級４位、元韓...
#   データソース:https://www.lifetime-boxing-fights.tdc.ne.jp/
# 0                                       登録日:20230514
# ...
